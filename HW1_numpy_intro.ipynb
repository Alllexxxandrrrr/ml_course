# %% [markdown]
# <a href="https://colab.research.google.com/github/Alllexxxandrrrr/ml_course/blob/main/HW1_numpy_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
print("Версия NumPy:", np.__version__)
# Out:
# Версия NumPy: 2.0.2

# %%
# Создаём массив
arr = np.array([1, 2, 3, 4, 5])
print("Массив:", arr)
print("Размерность:", arr.shape)
print("Среднее значение:", arr.mean())
# Out:
# Массив: [1 2 3 4 5]
# Размерность: (5,)
# Среднее значение: 3.0
